# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
Ze_read = pd.read_csv('RawWifiScans-39ff.csv')

# %%
def calculate_iqr_and_bounds(data, column):

    Q1 = data[column].quantile(0.25)
    Q3 = data[column].quantile(0.75)
    IQR = Q3 - Q1
    Low = Q1 - 1.5 * IQR
    Up = Q3 + 1.5 * IQR
    
    return {
        "Q1": Q1,
        "Q3": Q3,
        "IQR": IQR,
        "Lower Bound": Low,
        "Upper Bound": Up
    }

# %%
columns_to_analyze = ["RSS", "currentLocationX", "currentLocationY",
                       "centerFreq0", "centerFreq1", "floor", "channelWidth", "frequency"]

# %%
def visualize_outliers(data, column):

    plt.figure(figsize=(12, 6))
    sns.boxplot(x=data[column])
    plt.title(f"Boxplot of {column}")
    plt.show()

# %%
for column in columns_to_analyze:
    print(f"Analysis for column: {column}")
    results = calculate_iqr_and_bounds(Ze_read, column)
    for key, value in results.items():
        print(f"{key}: {value}")
    print("\n")

    visualize_outliers(Ze_read, column)
# Out:
# Analysis for column: RSS
# Q1: -87.0
# Q3: -69.0
# IQR: 18.0
# Lower Bound: -114.0
# Upper Bound: -42.0
# Analysis for column: currentLocationX
# Q1: 222.5722961
# Q3: 517.9237061
# IQR: 295.35141
# Lower Bound: -220.4548189
# Upper Bound: 960.9508211
# Analysis for column: currentLocationY
# Q1: 701.0444946
# Q3: 1239.225098
# IQR: 538.1806033999999
# Lower Bound: -106.22641049999982
# Upper Bound: 2046.4960030999996
# Analysis for column: centerFreq0
# Q1: 2437.0
# Q3: 5755.0
# IQR: 3318.0
# Lower Bound: -2540.0
# Upper Bound: 10732.0
# Analysis for column: centerFreq1
# Q1: 0.0
# Q3: 0.0
# IQR: 0.0
# Lower Bound: 0.0
# Upper Bound: 0.0
# Analysis for column: floor
# Q1: 1.0
# Q3: 1.0
# IQR: 0.0
# Lower Bound: 1.0
# Upper Bound: 1.0
# Analysis for column: channelWidth
# Q1: 0.0
# Q3: 2.0
# IQR: 2.0
# Lower Bound: -3.0
# Upper Bound: 5.0
# Analysis for column: frequency
# Q1: 2437.0
# Q3: 5745.0
# IQR: 3308.0
# Lower Bound: -2525.0
# Upper Bound: 10707.0
